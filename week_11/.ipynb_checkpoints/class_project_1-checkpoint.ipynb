# %%
# using pandas for project
# maybe use pyxl later

import pandas as pd

data = pd.read_csv("sis.csv")
# Out:
#     MatNo               Name  Age  Grade
# 0    1810       Aina Adeleke   16     80
# 1    1811        Sola Egbune   23     55
# 2    1812    Callistus Okeke   17     40
# 3    1813      Martin Alegbe   25     77
# 4    1814        Mary Akande   20     87
# 5    1815    Stella Olohimen   17     44
# 6    1816       Gabriel Pati   18     50
# 7    1817    Durojaiye Adamu   24     60
# 8    1818     Kolawole Alabi   18     67
# 9    1819      Tope Ogunleye   22     54
# 10   1820  Wilfred Nwachukwu   16     45
# 11   1821      Mildred James   15     70
# 12   1822     Glory Babalola   21     69
# 13   1823          Edith Ade   22     57
# 14   1824      Godwin Osahon   20     51
# 15   1825       Philip Odion   19     68

# %%
import pandas as pd

#data['Age']

class Students:
    
    data = pd.read_csv("sis.csv", index_col = "MatNo")
    pirates = dict(data)
    #thing= []
    #y = 0
    def set_group(self):
        for i in self.data['Age']:
            if i > 14 and i<18:
                #Pirates = pd.DataFrame(self.pirates)
                #Pirates.to_csv("The_Pirates")
                stuff = data.loc('1825')
                print(stuff)
                    
    
wow = Students()

wow.set_group()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     367         try:
# --> 368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
#
# KeyError: '1825'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-2cb9e0628634> in <module>
#      20 wow = Students()
#      21
# ---> 22 wow.set_group()
#
# <ipython-input-31-2cb9e0628634> in set_group(self)
#      14                 #Pirates = pd.DataFrame(self.pirates)
#      15                 #Pirates.to_csv("The_Pirates")
# ---> 16                 stuff = data.loc('1825')
#      17                 print(stuff)
#      18
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     582
#     583         if axis is not None:
# --> 584             axis = self.obj._get_axis_number(axis)
#     585         new_self.axis = axis
#     586         return new_self
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
# --> 370             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#     371
#     372     @classmethod
#
# ValueError: No axis named 1825 for object type DataFrame
