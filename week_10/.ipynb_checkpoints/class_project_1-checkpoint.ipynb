# %% [markdown]
# # CLASS PROJECT 1

# %%
class zenith():
    
    def __init__(self, name, division):
        self.name = name
        self.division = division
    
    def unique_services(self):
        
        self.uservices = ["Retirement and education accounts",
        "loans and mortgagges",
        "Checking and saving",
        "Multi-currency management services and products",
        "Foreign currency accounts",
        "Foreign currency credit cards",
        "Transborder advisory services",
        "Liquidity management",
        "Advisory services"]
        
        
    def mutual_services():
        self.mservices= ["Lines of credit",
       "Investment management and accounts",
       "Insurance"]

class RetailBanking(zenith):
    ru_services=["Retirement and education accounts, loans and mortgagges, Checking and saving"]
    rm_services= ["Lines of credit","Investment management and accounts","Insurance"]
    rbranch = "RETAIL"
   
    
    def unique_services(self):
        zenith.__init__(self,name,division)
        print("Name:", self.name)
        print("Division:", self.division)
        if self.division.upper() == self.rbranch:
            print("Unique services are",self.ru_services)
    
    def mutual_services(self):
        zenith.__init__(self,name,division)
        if self.division.upper() == self.rbranch:
            print("Mutual services are",self.rm_services)
        
class GlobalBanking(zenith):
  
    gu_services=["Multi-currency management services and products",
        "Foreign currency accounts",
        "Foreign currency credit cards",
        "Transborder advisory services",
        "Liquidity management"]
    
    gm_services= []
    gbranch = "GLOBAL"
   
    
    def unique_services(self):
        zenith.__init__(self,name,division)
        print("Name:", self.name)
        print("Division:", self.division)
        if self.division.upper() == self.gbranch:
            print("Unique services are",self.gu_services)
    
    def mutual_services(self):
        zenith.__init__(self,name,division)
        if self.division.upper() == self.gbranch:
            print("Mutual services are",self.gm_services)

class CommercialBanking(zenith):
    cu_services=["Advisory services"]
    
    cm_services= []
    cbranch = "COMMERCIAL"
   
    
    def unique_services(self):
        zenith.__init__(self,name,division)
        print("Name:", self.name)
        print("Division:", self.division)
        if self.division.upper() == self.cbranch:
            print("Unique services are",self.cu_services)
    
    def mutual_services(self):
        zenith.__init__(self,name,division)
        if self.division.upper() == self.cbranch:
            print("Mutual services are",self.cm_services)

    
name = input("State your name: ")
division = input("State your division: ")

employee = RetailBanking(name, division)
employee = GlobalBanking(name, division)
employee = CommercialBanking(name, division)


employee.unique_services()
employee.mutual_services()
# Out:
# State your name: d
# State your division: commercial
# Name: d
# Division: commercial
# Unique services are ['Advisory services']
# Mutual services are []
